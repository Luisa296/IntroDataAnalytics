# %% [markdown]
# # Exploración y Recolección de Datos con Joins en Fórmula 1
#
# Este notebook está diseñado para una clase práctica en la que se exploran y recolectan datos mediante la unión (_joins_) de múltiples datasets de Fórmula 1. El objetivo es analizar conjuntamente información procedente de diferentes orígenes para responder preguntas de negocio y obtener insights sobre la historia de la F1.
#
# ## Objetivos de la Clase
#
# 1. Comprender el uso de joins para combinar tablas utilizando claves comunes (por ejemplo, `raceId` y `driverId`).
# 2. Explorar la integración de datos provenientes de archivos distintos y su impacto en la información resultante.
# 3. Responder a preguntas de negocio como:
#    - ¿Cuántos pilotos han participado en la F1?
#    - ¿Cuál es el circuito que ha sido más utilizado?
#    - ¿Qué piloto ha ganado más carreras?
#    - ¿Qué piloto ha acumulado más puntos durante su carrera?
# 4. Interpretar gráficamente resultados y tendencias a lo largo del tiempo.
#
# La idea es que, mediante el uso de operaciones join, los estudiantes unan y analicen datos de varias fuentes (por ejemplo, `races.csv`, `results.csv` y `drivers.csv`) para elaborar un análisis exploratorio completo.

# %%
# !wget https://github.com/javierherrera1996/lecture_analytics/raw/main/f1stasts_1.zip
# !unzip f1stasts_1.zip
# Out:
# --2025-04-24 03:20:24--  https://github.com/javierherrera1996/lecture_analytics/raw/main/f1stasts_1.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/javierherrera1996/lecture_analytics/main/f1stasts_1.zip [following]
# --2025-04-24 03:20:24--  https://raw.githubusercontent.com/javierherrera1996/lecture_analytics/main/f1stasts_1.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6183969 (5.9M) [application/zip]
# Saving to: ‘f1stasts_1.zip’
#
# f1stasts_1.zip      100%[===================>]   5.90M  --.-KB/s    in 0.1s
#
# ...

# %% [markdown]
# ## 1. Carga y Exploración de los Datos
#
# En esta sección se cargan y revisan brevemente los datasets principales:
#
# - **races.csv:** Contiene detalles de cada carrera (año, circuito, fecha, etc.).
# - **results.csv:** Registra los resultados de cada carrera (posición, puntos, vueltas, etc.).
# - **drivers.csv:** Información sobre cada piloto (nombre, nacionalidad, fecha de nacimiento, etc.).
#
# Asegúrate de tener estos archivos en tu entorno de trabajo.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Análisis Preliminar y Preparación de los Datos
#
# Antes de realizar las uniones, es importante revisar las columnas clave de cada DataFrame:
#
# - En **races_df** utilizaremos `raceId` para identificar la carrera.
# - En **results_df** también se emplea `raceId` y `driverId` para enlazar resultados y pilotos.
# - En **drivers_df** `driverId` es la clave para identificar a cada piloto.
#
# Realiza un análisis exploratorio básico (conteos, tipos de dato, detección de nulos) para asegurarte de la calidad de la información.

# %%
race_df = pd.read_csv('races.csv')
results_df = pd.read_csv('results.csv')
drivers_df = pd.read_csv('drivers.csv')

# %%
race_df
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 0          1  2009      1          1     Australian Grand Prix  2009-03-29
# 1          2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4        Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                       ...         ...
# 1096    1116  2023     18         69  United States Grand Prix  2023-10-22
# 1097    1117  2023     19         32    Mexico City Grand Prix  2023-10-29
# 1098    1118  2023     20         18      São Paulo Grand Prix  2023-11-05
# 1099    1119  2023     21         80      Las Vegas Grand Prix  2023-11-19
# 1100    1120  2023     22         24      Abu Dhabi Grand Prix  2023-11-26
#
# ...

# %%
for col in race_df.columns:
  race_df.loc[race_df[col]=='\\N',col]= np.nan

# %%
race_df
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# ...

# %%
race_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   raceId       1101 non-null   float64
#  1   year         1101 non-null   float64
#  2   round        1101 non-null   float64
#  3   circuitId    1101 non-null   float64
#  4   name         1101 non-null   object
#  5   date         1101 non-null   object
#  6   time         370 non-null    object
#  7   url          1101 non-null   object
#  8   fp1_date     66 non-null     object
#  9   fp1_time     44 non-null     object
#  10  fp2_date     66 non-null     object
#  11  fp2_time     44 non-null     object
#  12  fp3_date     54 non-null     object
#  13  fp3_time     35 non-null     object
#  14  quali_date   66 non-null     object
#  15  quali_time   44 non-null     object
#  16  sprint_date  12 non-null     object
#  17  sprint_time  9 non-null      object
# ...

# %%
race_df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# ...

# %%
race_df.isnull().sum()
# Out:
# raceId            0
# year              0
# round             0
# circuitId         0
# name              0
# date              0
# time            731
# url               0
# fp1_date       1035
# fp1_time       1057
# fp2_date       1035
# fp2_time       1057
# fp3_date       1047
# fp3_time       1066
# quali_date     1035
# quali_time     1057
# sprint_date    1089
# sprint_time    1092
# dtype: int64

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26080 entries, 0 to 26079
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         26080 non-null  int64
#  1   raceId           26080 non-null  int64
#  2   driverId         26080 non-null  int64
#  3   constructorId    26080 non-null  int64
#  4   number           26080 non-null  object
#  5   grid             26080 non-null  int64
#  6   position         26080 non-null  object
#  7   positionText     26080 non-null  object
#  8   positionOrder    26080 non-null  int64
#  9   points           26080 non-null  float64
#  10  laps             26080 non-null  int64
#  11  time             26080 non-null  object
#  12  milliseconds     26080 non-null  object
#  13  fastestLap       26080 non-null  object
#  14  rank             26080 non-null  object
#  15  fastestLapTime   26080 non-null  object
#  16  fastestLapSpeed  26080 non-null  object
# ...

# %%
results_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
results_df.isnull().sum()
# Out:
# resultId           0
# raceId             0
# driverId           0
# constructorId      0
# number             0
# grid               0
# position           0
# positionText       0
# positionOrder      0
# points             0
# laps               0
# time               0
# milliseconds       0
# fastestLap         0
# rank               0
# fastestLapTime     0
# fastestLapSpeed    0
# statusId           0
# dtype: int64

# %%
drivers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     857 non-null    int64
#  1   driverRef    857 non-null    object
#  2   number       857 non-null    object
#  3   code         857 non-null    object
#  4   forename     857 non-null    object
#  5   surname      857 non-null    object
#  6   dob          857 non-null    object
#  7   nationality  857 non-null    object
#  8   url          857 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 60.4+ KB

# %%
drivers_df.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
drivers_df.isnull().sum()
# Out:
# driverId       0
# driverRef      0
# number         0
# code           0
# forename       0
# surname        0
# dob            0
# nationality    0
# url            0
# dtype: int64

# %% [markdown]
# ## 3. Integración de Datos mediante Joins
#
# El objetivo es unir la información de las distintas tablas para poder responder a preguntas de negocio. En este ejercicio central, se utilizarán joins para obtener insights combinando datos de carreras, resultados y pilotos.
#
# ### 3.1 Unir `results_df` y `drivers_df`
#
# Para analizar la participación y resultados de cada piloto, realizamos un merge entre `results_df` y `drivers_df` utilizando la clave `driverId`.
#
# **Pregunta clave:** ¿Cuántos pilotos distintos han participado en la F1?
#
# Utiliza el DataFrame resultante para explorar esta pregunta.

# %%
df_resultados = pd.merge(results_df, drivers_df, on='driverId', how='inner')
df_resultados
# Out:
#        resultId  raceId  driverId  constructorId number_x  grid position  \
# 0             1      18         1              1       22     1        1
# 1             2      18         2              2        3     5        2
# 2             3      18         3              3        7     7        3
# 3             4      18         4              4        5    11        4
# 4             5      18         5              1       23     3        5
# ...         ...     ...       ...            ...      ...   ...      ...
# 26075     26081    1110       817            213        3    19       16
# 26076     26082    1110       858              3        2    18       17
# 26077     26083    1110       807            210       27     0       18
# 26078     26084    1110       832              6       55     4       \N
# 26079     26085    1110       857              1       81     5       \N
#
#       positionText  positionOrder  points  ...  fastestLapSpeed statusId  \
# ...

# %%
num_drivers = df_resultados['driverId'].nunique()
print(f"Número de pilotos distintos que han participado en la F1: {num_drivers}")
# Out:
# Número de pilotos distintos que han participado en la F1: 857

# %% [markdown]
# ### 3.2. Unir `df_resultados` con `races_df`
#
# Ahora, para relacionar los resultados con cada carrera, se efectúa la unión entre el DataFrame obtenido (`df_resultados`) y `races_df` a través de la clave `raceId`.
#
# **Pregunta clave:** ¿Qué información adicional sobre cada carrera (fecha, circuito, etc.) se puede incorporar para enriquecer el análisis?
#
# Respuesta:  Al fusionar df_resultados con races_df se enriquece el dataframe con datos de F1 como fecha, año, ID del circuito (permite el análisis específico de cada circuito y la comparación del rendimiento en los diferentes circuitos), entre otras. Con este nuevo dataframe se puede realizar análisis más profundos, lo que proporciona una comprensión más completa del conjunto de datos de F1 y puede revelar patrones o tendencias.
#
#
# Explora y analiza cómo afecta esta integración en el conjunto de datos final.

# %%
df_completo = pd.merge(df_resultados, race_df, on='raceId', how='inner')
df_completo
# Out:
#        resultId  raceId  driverId  constructorId number_x  grid position  \
# 0             1      18         1              1       22     1        1
# 1             2      18         2              2        3     5        2
# 2             3      18         3              3        7     7        3
# 3             4      18         4              4        5    11        4
# 4             5      18         5              1       23     3        5
# ...         ...     ...       ...            ...      ...   ...      ...
# 26075     26081    1110       817            213        3    19       16
# 26076     26082    1110       858              3        2    18       17
# 26077     26083    1110       807            210       27     0       18
# 26078     26084    1110       832              6       55     4       \N
# 26079     26085    1110       857              1       81     5       \N
#
#       positionText  positionOrder  points  ...    fp1_date  fp1_time  \
# ...

# %%
df_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26080 entries, 0 to 26079
# Data columns (total 43 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         26080 non-null  int64
#  1   raceId           26080 non-null  int64
#  2   driverId         26080 non-null  int64
#  3   constructorId    26080 non-null  int64
#  4   number_x         26080 non-null  object
#  5   grid             26080 non-null  int64
#  6   position         26080 non-null  object
#  7   positionText     26080 non-null  object
#  8   positionOrder    26080 non-null  int64
#  9   points           26080 non-null  float64
#  10  laps             26080 non-null  int64
#  11  time_x           26080 non-null  object
#  12  milliseconds     26080 non-null  object
#  13  fastestLap       26080 non-null  object
#  14  rank             26080 non-null  object
#  15  fastestLapTime   26080 non-null  object
#  16  fastestLapSpeed  26080 non-null  object
# ...

# %% [markdown]
# ## 4. Análisis Conjunto y Ejercicios Interactivos
#
# Con el DataFrame combinado (`df_completo`) podremos responder a varias preguntas de negocio y realizar análisis conjuntos. A continuación se proponen algunos ejercicios:
#
# ### Ejercicio 1: Identificar el Circuito Más Utilizado
#
# Utiliza `races_df` y la información del DataFrame combinado para determinar cuál es el circuito (identificado con `circuitId` o el nombre del circuito, si se encuentra) que ha sido sede de la mayor cantidad de carreras.
#
# **Sugerencia:** Usa la función `value_counts()` y discute el resultado con los estudiantes.

# %%
circuit_counts = df_completo['name'].value_counts()
circuit_counts
# Out:
# name
# British Grand Prix               1853
# Italian Grand Prix               1824
# Monaco Grand Prix                1644
# German Grand Prix                1599
# Belgian Grand Prix               1577
# French Grand Prix                1484
# Canadian Grand Prix              1271
# Spanish Grand Prix               1256
# Brazilian Grand Prix             1163
# United States Grand Prix         1009
# Hungarian Grand Prix              891
# Australian Grand Prix             870
# Austrian Grand Prix               861
# Japanese Grand Prix               842
# Dutch Grand Prix                  727
# San Marino Grand Prix             667
# South African Grand Prix          581
# European Grand Prix               528
# Mexican Grand Prix                478
# Portuguese Grand Prix             453
# Argentine Grand Prix              448
# Malaysian Grand Prix              412
# Indianapolis 500                  405
# Bahrain Grand Prix                400
# ...

# %% [markdown]
# ### Ejercicio 2: Piloto con Más Victorias
#
# Filtra el DataFrame combinado para quedarte con aquellos registros donde la posición final (`position`) sea 1, lo que indica una victoria. Luego, agrupa por piloto para determinar quién ha ganado más carreras.
#
# **Pregunta para los estudiantes:** _¿Qué piloto se destaca por su número de victorias y cómo se relaciona este dato con otros indicadores de rendimiento?_
#
# Respuesta: El piloto que se destaca por su número de victorias es Hamilton. Este logro está estrechamente relacionado con otros indicadores de rendimiento como
# la puntuación total acumulada y los podios, lo que lo coloca entre los mejores pilotos. Otros factores como el rendimiento del coche, la estrategia de equipo y su gran habilidad manejando lo han ayudado a destacar en la Fómula 1

# %%
victorias_df = df_completo[df_completo['position'] == '1']
victorias_df
# Out:
#        resultId  raceId  driverId  constructorId number_x  grid position  \
# 0             1      18         1              1       22     1        1
# 22           23      19         8              6        1     2        1
# 44           45      20        13              6        2     2        1
# 66           67      21         8              6        1     1        1
# 88           89      22        13              6        2     1        1
# ...         ...     ...       ...            ...      ...   ...      ...
# 25980     25986    1106       830              9        1     1        1
# 26000     26006    1107       830              9        1     1        1
# 26020     26026    1108       830              9        1     1        1
# 26040     26046    1109       830              9        1     2        1
# 26060     26066    1110       830              9        1     6        1
#
#       positionText  positionOrder  points  ...    fp1_date  fp1_time  \
# ...

# %%
pilotos_victorias = victorias_df.groupby('driverRef')['position'].count().sort_values(ascending=False)
pilotos_victorias
# Out:
# driverRef
# hamilton              103
# michael_schumacher     91
# vettel                 53
# prost                  51
# max_verstappen         45
#                      ...
# sweikert                1
# taruffi                 1
# trulli                  1
# ward                    1
# wallard                 1
# Name: position, Length: 113, dtype: int64

# %% [markdown]
# ### Ejercicio 3: Piloto con Más Puntos
#
# Agrupa el DataFrame combinado para sumar el total de puntos (`points`) obtenidos por cada piloto a lo largo de su carrera.
#
# **Pregunta para los estudiantes:** _¿Existe correlación entre el número de victorias y la suma total de puntos? ¿Qué puede influir en esta relación?_
#
# Respuesta: Si existe una correlación entre el número de victorias y la suma total de puntos ya que vemos que en el podio de puntos esta Hamilton, Vettel y Max mientras que en el podio de victorias esta Hamilton, Michael y Vettel. Los pilotos que ganan más carreras tienden a tener un mayor total de puntos. En esta relación pueden influir factores como la consistencia del piloto en quedar en posiciones altas en la mayoria de carreras,  el rendimiento del carro, la puntuación de cada carrera, entre otros

# %%
driver_points = df_completo.groupby('driverRef')['points'].sum().sort_values(ascending=False)
driver_points
# Out:
# driverRef
# hamilton          4540.5
# vettel            3098.0
# max_verstappen    2275.5
# alonso            2203.0
# raikkonen         1873.0
#                    ...
# hesnault             0.0
# heyer                0.0
# hirt                 0.0
# hobbs                0.0
# hayje                0.0
# Name: points, Length: 857, dtype: float64

# %% [markdown]
# ### Ejercicio 4: Distribución de Nacionalidades de los Pilotos
#
# Analiza la columna `nationality` presente en `drivers_df` para determinar qué nacionalidades están mejor representadas en la F1. Realiza un gráfico de pastel para visualizar la distribución de pilotos por país.
#
# **Debate:** ¿Qué factores históricos o deportivos crees que puedan explicar esta distribución?
#
# Respuesta: Los factores históricos y deportivos que pueden explicar la distribución de la nacionalidad de los pilotos de F1 pueden ser la fuerte tradición y cultura del automovilismo en ciertos países como Reino Unido, Italia, Alemania. Factores económicos que facilitan el acceso a formación, infraestructura y patrocinio en este deporte. La existencia de programas de desarrollo de pilotos que impulsan a los jóvenes aspirantes y el interés nacional en el automovilismo.

# %%
nationality_counts=df_completo['nationality'].value_counts()
nationality_counts
# Out:
# nationality
# British              4454
# Italian              3418
# French               3028
# German               2396
# Brazilian            1953
# American             1291
# Finnish              1159
# Spanish               846
# Australian            835
# Austrian              690
# Japanese              647
# Belgian               591
# Swedish               510
# Dutch                 502
# Swiss                 496
# Canadian              464
# Mexican               434
# New Zealander         396
# Argentine             373
# Russian               213
# South African         210
# Danish                189
# Monegasque            144
# Colombian             125
# Venezuelan            120
# Polish                 99
# Irish                  92
# Thai                   90
# Portuguese             87
# Indian                 59
# Chilean                37
# Chinese                34
# Hungarian              20
# Rhodesian              18
# Malaysian              16
# ...

# %%
plt.figure(figsize=(10, 10))
plt.pie(nationality_counts.values, labels=nationality_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of F1 Drivers by Nationality')
# Out:
# Text(0.5, 1.0, 'Distribution of F1 Drivers by Nationality')

# %%
top_9 = nationality_counts[:9]
other_count = nationality_counts[9:].sum()
pie_data = pd.concat([top_9, pd.Series([other_count], index=['Others'])])
pie_data
# Out:
# British       4454
# Italian       3418
# French        3028
# German        2396
# Brazilian     1953
# American      1291
# Finnish       1159
# Spanish        846
# Australian     835
# Others        6700
# dtype: int64

# %%
plt.figure(figsize=(10, 10))
plt.pie(pie_data.values, labels=pie_data.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of F1 Drivers by Nationality (Top 9 + Others)')
plt.show()

# %% [markdown]
# ### Ejercicio 5: Evolución del Número de Carreras por Año
#
# Genera un gráfico de barras que muestre cómo ha evolucionado el número de carreras a lo largo de los años, utilizando la información de `races_df`.
#
# **Pregunta para los estudiantes:** _¿Qué eventos o cambios en la industria (por ejemplo, crisis, cambios en el reglamento) podrían explicar las variaciones observadas a lo largo de la historia?_
#
# Respuesta: Diversos factores pueden influir en la cantidad de carreras de Fórmula 1 que se realizan en una temporada. Las crisis económicas mundiales pueden afectar la financiación y el patrocinio del automovilismo, reduciendo el número de competencias. Asimismo, los cambios importantes en el reglamento, como las normas técnicas o de seguridad, pueden aumentar los costos y la complejidad, afectando la participación de los equipos. La inestabilidad política en ciertas regiones también puede causar la cancelación o el aplazamiento de carreras.
#
# Este ejercicio ayudará a vincular el análisis de datos con contextos históricos y comerciales.

# %%
races_per_year = df_completo.groupby('year')['raceId'].count()
races_per_year
# Out:
# year
# 1950.0    160
# 1951.0    179
# 1952.0    215
# 1953.0    246
# 1954.0    230
#          ...
# 2019.0    420
# 2020.0    340
# 2021.0    440
# 2022.0    440
# 2023.0    240
# Name: raceId, Length: 74, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.bar(races_per_year.index, races_per_year.values)
plt.xlabel("Year")
plt.ylabel("Number of Races")
plt.title("Evolution of Number of Races Over the Years")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
victorias_df = df_completo[df_completo['position'] == '1']

pilotos_victorias = victorias_df.groupby('driverRef')['position'].count().sort_values(ascending=False)

top_10_pilotos = pilotos_victorias.head(10)

plt.figure(figsize=(10, 6))
plt.barh(top_10_pilotos.index, top_10_pilotos.values,color='crimson')
plt.xlabel("Número de Victorias")
plt.ylabel("Pilotos")
plt.title("Top 10 Pilotos con Más Victorias")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
driver_points = df_completo.groupby('driverRef')['points'].sum().sort_values(ascending=False)

top_10_points = driver_points.head(10)

driver_races = df_completo.groupby('driverRef')['raceId'].nunique()

plt.figure(figsize=(10, 6))
plt.bar(top_10_points.index, top_10_points.values, color='crimson')
plt.xlabel("Pilotos")
plt.ylabel("Puntos Acumulados")
plt.title("Top 10 Pilotos con Más Puntos Acumulados")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
total_drivers = df_completo['driverRef'].nunique()
print(f"El total de drivers es: {total_drivers}")
# Out:
# El total de drivers es: 857

# %%
wins_df = df_completo[df_completo['position'] == '1']

driver_wins = wins_df.groupby('driverRef')['position'].count().sort_values(ascending=False)

top_50_drivers = driver_wins.head(50).index.tolist()

top_50_df = df_completo[df_completo['driverRef'].isin(top_10_drivers)]

nationality_counts = top_50_df.groupby('nationality')['driverRef'].nunique()

num_colors = len(nationality_counts)
colors = cm.Reds(np.linspace(0.1, 1, num_colors))

plt.figure(figsize=(8, 8))
plt.pie(nationality_counts.values, labels=nationality_counts.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Nationalities of Top 50 Drivers with Most Wins')
plt.show()

# %%
driver_stats = df_completo.groupby('driverRef').agg(total_points=('points', 'sum'), total_races=('raceId', 'nunique'))

filtered_drivers = driver_stats[driver_stats['total_races'] >= 50].copy()

filtered_drivers.loc[:, 'avg_points'] = filtered_drivers['total_points'] / filtered_drivers['total_races']
sorted_drivers = filtered_drivers.sort_values('avg_points', ascending=False)

top_10_avg_points = sorted_drivers.head(10)

plt.figure(figsize=(10, 6))
plt.bar(top_10_avg_points.index, top_10_avg_points['avg_points'], color='crimson')
plt.xlabel("Pilotos")
plt.ylabel("Promedio de Puntos por Carrera")
plt.title("Top 10 Pilotos con Mayor Promedio de Puntos (Mínimo 50 Carreras)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
driver_stats = df_completo.groupby('driverRef').agg(
    total_wins=('position', lambda x: (x == '1').sum()),
    total_races=('raceId', 'nunique'))

filtered_drivers = driver_stats[driver_stats['total_races'] >= 50].copy()

filtered_drivers.loc[:, 'win_ratio'] = filtered_drivers['total_wins'] / filtered_drivers['total_races']

sorted_drivers = filtered_drivers.sort_values('win_ratio', ascending=False)

top_10_win_ratio = sorted_drivers.head(10)

plt.figure(figsize=(10, 6))
plt.plot(top_10_win_ratio.index, top_10_win_ratio['win_ratio'], marker='o', color='crimson')
plt.xlabel("Pilotos")
plt.ylabel("Ratio de Victorias")
plt.title("Top 10 Pilotos con Mayor Ratio de Victorias (Mínimo 50 Carreras)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
pilotos_destacados = ['hamilton', 'vettel', 'alonso']

datos_evolucion = pd.DataFrame()

for piloto in pilotos_destacados:
    datos_piloto = df_completo[df_completo['driverRef'] == piloto]
    puntos_por_año = datos_piloto.groupby('year')['points'].sum()
    datos_evolucion[piloto] = puntos_por_año

plt.figure(figsize=(12, 6))

colores = {'hamilton': 'red', 'vettel': 'blue', 'alonso': 'green'}

for piloto in pilotos_destacados:
    plt.plot(datos_evolucion.index, datos_evolucion[piloto], label=piloto, color=colores[piloto])

plt.xlabel("Año")
plt.ylabel("Puntos Acumulados")
plt.title("Evolución Histórica de la Competencia")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Preguntas para el Análisis Conjunto y Debate en Clase
#
# Para concluir la actividad, propón a los estudiantes debatir y responder a las siguientes preguntas:
#
# 1. **Integración y Calidad de Datos:** ¿Qué inconvenientes pueden surgir al unir tablas que tienen registros incompletos o duplicados? ¿Cómo solucionarlo?
# 2. **Estrategias de Join:** ¿En qué casos es más adecuado usar un `inner join` y cuándo un `outer join` para evitar perder información relevante?
# 3. **Insights Negocio:** Basándose en los resultados obtenidos (pilotos con más victorias/puntos, circuitos más usados, etc.), ¿qué estrategias de negocio o insights se podrían extraer para equipos o patrocinadores en la F1?
# 4. **Análisis Temporal:** ¿Qué relación existe entre los cambios en el número de carreras por año y otros indicadores (como el número de pilotos, eventos destacados, etc.)?
#
# Estas preguntas tienen el objetivo de invitar a un análisis integral de los datos, combinando la técnica de joins con la interpretación y contextualización de los resultados.
#
# Respuestas:
# 1. Al unir tablas que tienen registros incompletos o duplicados se pueden presentar inconvenientes como la la pérdida de información, resultados sesgados o conteos inflados. Para solucionarlo es necesario limpiar los datos, asegurarse de que estos sean coherentes y usar la estrategia de join adecuada
# 2. Es mejor usar inner join cuando solo se necesitan los datos que tienen coincidencias en ambas tablas. Es mejor usar outer join cuando quieres asegurarte de no perder datos de una de las tablas, incluso si no hay coincidencia en la otra.
# 3. Insights de negocio y estrategias:
#   - La presencia dominante de pilotos como Lewis Hamilton, Vettel y Max en los podios de puntos y victorias muestra que asociarse con pilotos de alto rendimiento ofrece visibilidad global, credibilidad deportiva y conexión con una base de fans sólida. Esto representa una gran oportunidad para marcas que buscan posicionamiento internacional.
#   - El circuito más usado es el British Grand Prix y la nacionalidad más común entre los pilotos es la británica, lo que resalta la importancia del Reino Unido en la historia y actualidad de la F1. Tanto equipos como patrocinadores pueden beneficiarse al enfocarse en el mercado británico.
#   - La evolución del número de carreras muestra una expansión significativa hasta finales de los 80 y  estabilización en las últimas décadas. Se debe priorizar carreras estratégicas con mayor retorno de inversión.
# 4. La relación entre los cambios en el número de carreras por año y otros indicadores se puede observar en:
#   - Un mayor número de carreras atrae a más pilotos y genera mayor interés en el deporte.
#   - Los cambios en la normativa influyen en el número de carreras y la participación de los pilotos
#   - Con este análisis se pueden identificar tendencias que permitan diseñar de manera efectiva estrategias

# %% [markdown]
# ## 6. Conclusión
#
# Este ejercicio integrador ha permitido utilizar joins para combinar distintos orígenes de datos y explorar de manera conjunta información esencial de la Fórmula 1. Se ha trabajado en:
#
# - La identificación de claves y la integración de múltiples datasets.
# - La generación de indicadores y visualizaciones útiles para responder preguntas de negocio.
# - El análisis crítico y debate sobre la calidad de los datos y la metodología de integración.
#
# Utiliza este notebook como una herramienta para profundizar en la recolección y exploración de datos, incentivando a los estudiantes a buscar conexiones entre la teoría de joins y su aplicación en casos reales.
